# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("all_data.csv")
df.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
df.shape
# Out:
# (96, 4)

# %%
print(df.Country.unique())
# Out:
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']

# %%
print(df.Year.unique())
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015]

# %%
df = df.rename({"Life expectancy at birth (years)":"LEABY"}, axis = "columns")
df.head()
# Out:
#   Country  Year  LEABY           GDP
# 0   Chile  2000   77.3  7.786093e+10
# 1   Chile  2001   77.3  7.097992e+10
# 2   Chile  2002   77.8  6.973681e+10
# 3   Chile  2003   77.9  7.564346e+10
# 4   Chile  2004   78.0  9.921039e+10

# %%
plt.figure(figsize=(10,6))
sns.histplot(df.GDP, kde=False)
plt.xlabel("GDP in Trillions of U.S. Dollars")
# Out:
# Text(0.5, 0, 'GDP in Trillions of U.S. Dollars')

# %%
plt.figure(figsize=(10,6))
sns.distplot(df.LEABY, kde=False)
plt.xlabel("Life expectancy at birth")
# Out:
# /Users/Macintosh/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Life expectancy at birth')

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x=df.Country, y=df.LEABY, estimator=np.mean, ci="sd")
plt.xlabel("Life expectancy at birth by country")
# Out:
# Text(0.5, 0, 'Life expectancy at birth by country')

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x="Country", y="GDP", ci="sd", estimator=np.mean)
plt.xlabel("GDP by Country")
# Out:
# Text(0.5, 0, 'GDP by Country')

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
sns.violinplot(data=df, x="Country",y="GDP")
plt.title("GDP by country")
plt.xticks(rotation=45)
plt.subplot(1,2,2)
sns.violinplot(data=df,x="Country",y="LEABY")
plt.xticks(rotation=45)
plt.title("Life expectancy by country")
# Out:
# Text(0.5, 1.0, 'Life expectancy by country')

# %%
fig, axes=plt.subplots(1,2,figsize=(18,6))
axes[0]=sns.swarmplot(ax=axes[0],x=df.Country,y=df.GDP)
axes[0].set_title("GDP by country")
axes[0].set_xticklabels(axes[0].get_xticklabels(),rotation=45)
axes[1]=sns.swarmplot(ax=axes[1],x=df.Country,y=df.LEABY)
axes[1].set_title("Life expectancy by country")
axes[1].set_xticklabels(axes[1].get_xticklabels(),rotation=45)
# Out:
# /Users/Macintosh/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 31.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# [Text(0, 0, 'Chile'),
#  Text(1, 0, 'China'),
#  Text(2, 0, 'Germany'),
#  Text(3, 0, 'Mexico'),
#  Text(4, 0, 'United States of America'),
#  Text(5, 0, 'Zimbabwe')]

# %%
plt.figure(figsize=(13,10))
sns.lineplot(x=df.Year, y=df.GDP, hue=df.Country)
plt.legend(loc="upper left")

# %%
graphGDP = sns.FacetGrid(df, col="Country", col_wrap=3, hue = "Country", sharey=False )
graphGDP = (graphGDP.map(sns.lineplot,"Year","GDP")
         .add_legend()
         .set_axis_labels("Year","GDP in Trillions of U.S. Dollars"))

graphGDP;

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x=df.Year, y=df.LEABY, hue=df.Country)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
plt.ylabel("Life expectancy at birth (years)")
# Out:
# Text(0, 0.5, 'Life expectancy at birth (years)')

# %%
graphLEABY = sns.FacetGrid(df, col="Country", col_wrap=3,
                      hue = "Country", sharey = False)

graphLEABY = (graphLEABY.map(sns.lineplot,"Year","LEABY")
         .add_legend()
         .set_axis_labels("Year","Life expectancy at birth (years)"))

graphLEABY

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df.LEABY, y=df.GDP, hue=df.Country).legend(loc='upper left')
